# %% [markdown]
# ## Practical no :1
# ### Creating & Visualizing Neural Network for the given data. (Use python)
# ### Note: download dataset using Kaggal. Keras, ANN visualizer, graph viz libraries are required.

# %%
import graphviz
import keras
import ann_visualizer

# %%
# create your first MLP in keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter = ",")

# %%
# split into input (x) and output (Y) variables
x = dataset[:,0:8]
y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#compile model
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
#fit the model
model.fit(x, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 3.7110 - accuracy: 0.6406
# Epoch 2/150
# 77/77 [==============================] - 0s 2ms/step - loss: 2.4860 - accuracy: 0.6146
# Epoch 3/150
# 77/77 [==============================] - 0s 2ms/step - loss: 2.0098 - accuracy: 0.6159
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.6179 - accuracy: 0.6120
# Epoch 5/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.4058 - accuracy: 0.6185
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.1805 - accuracy: 0.6250
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.1011 - accuracy: 0.6367
# Epoch 8/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.0558 - accuracy: 0.6341
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9512 - accuracy: 0.6497
# Epoch 10/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8476 - accuracy: 0.6523
# Epoch 11/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8063 - accuracy: 0.6510
# Epoch 12/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7829 - accuracy: 0.6641
# Epoch 13/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7624 - accuracy: 0.6667
# Epoch 14/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7316 - accuracy: 0.6862
# Epoch 15/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7080 - accuracy: 0.6745
# Epoch 16/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6746 - accuracy: 0.6901
# Epoch 17/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6682 - accuracy: 0.6940
# Epoch 18/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6574 - accuracy: 0.6771
# Epoch 19/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6701 - accuracy: 0.6940
# Epoch 20/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6423 - accuracy: 0.6797
# Epoch 21/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6374 - accuracy: 0.6914
# Epoch 22/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6262 - accuracy: 0.6901
# Epoch 23/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6030 - accuracy: 0.6953
# Epoch 24/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6089 - accuracy: 0.6875
# Epoch 25/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6392 - accuracy: 0.7018
# Epoch 26/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.6849
# Epoch 27/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6213 - accuracy: 0.7161
# Epoch 28/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5973 - accuracy: 0.6888
# Epoch 29/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5905 - accuracy: 0.7044
# Epoch 30/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6031 - accuracy: 0.6823
# Epoch 31/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6020 - accuracy: 0.6979
# Epoch 32/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6187 - accuracy: 0.6849
# Epoch 33/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5797 - accuracy: 0.6823
# Epoch 34/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5865 - accuracy: 0.6992
# Epoch 35/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5866 - accuracy: 0.7070
# Epoch 36/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5778 - accuracy: 0.7188
# Epoch 37/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6018 - accuracy: 0.6953
# Epoch 38/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5893 - accuracy: 0.6979
# Epoch 39/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5662 - accuracy: 0.7227
# Epoch 40/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5905 - accuracy: 0.7083
# Epoch 41/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5701 - accuracy: 0.7148
# Epoch 42/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5637 - accuracy: 0.7096
# Epoch 43/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5610 - accuracy: 0.7070
# Epoch 44/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5485 - accuracy: 0.7174
# Epoch 45/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5471 - accuracy: 0.7253
# Epoch 46/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5659 - accuracy: 0.7148
# Epoch 47/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5619 - accuracy: 0.7214
# Epoch 48/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5590 - accuracy: 0.7383
# Epoch 49/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5747 - accuracy: 0.7083
# Epoch 50/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5787 - accuracy: 0.7305
# Epoch 51/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.7279
# Epoch 52/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5659 - accuracy: 0.7188
# Epoch 53/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5610 - accuracy: 0.7240
# Epoch 54/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5542 - accuracy: 0.7318
# Epoch 55/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5619 - accuracy: 0.7161
# Epoch 56/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5516 - accuracy: 0.7253
# Epoch 57/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5774 - accuracy: 0.7122
# Epoch 58/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5538 - accuracy: 0.7214
# Epoch 59/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5489 - accuracy: 0.7370
# Epoch 60/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5555 - accuracy: 0.7305
# Epoch 61/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5441 - accuracy: 0.7214
# Epoch 62/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5456 - accuracy: 0.7253
# Epoch 63/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5312 - accuracy: 0.7383
# Epoch 64/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5487 - accuracy: 0.7266
# Epoch 65/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5360 - accuracy: 0.7344
# Epoch 66/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5679 - accuracy: 0.7240
# Epoch 67/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5411 - accuracy: 0.7383
# Epoch 68/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5722 - accuracy: 0.7174
# Epoch 69/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5393 - accuracy: 0.7435
# Epoch 70/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5455 - accuracy: 0.7240
# Epoch 71/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7474
# Epoch 72/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5432 - accuracy: 0.7370
# Epoch 73/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5286 - accuracy: 0.7448
# Epoch 74/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5317 - accuracy: 0.7422
# Epoch 75/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5460 - accuracy: 0.7331
# Epoch 76/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5573 - accuracy: 0.7201
# Epoch 77/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7344
# Epoch 78/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7435
# Epoch 79/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5353 - accuracy: 0.7409
# Epoch 80/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7148
# Epoch 81/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5559 - accuracy: 0.7409
# Epoch 82/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5331 - accuracy: 0.7188
# Epoch 83/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5319 - accuracy: 0.7409
# Epoch 84/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5385 - accuracy: 0.7396
# Epoch 85/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5326 - accuracy: 0.7461
# Epoch 86/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5287 - accuracy: 0.7370
# Epoch 87/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.7122
# Epoch 88/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5470 - accuracy: 0.7422
# Epoch 89/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5397 - accuracy: 0.7409
# Epoch 90/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.7135
# Epoch 91/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.7383
# Epoch 92/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.7461
# Epoch 93/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5352 - accuracy: 0.7279
# Epoch 94/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.7370
# Epoch 95/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5646 - accuracy: 0.7253
# Epoch 96/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5199 - accuracy: 0.7487
# Epoch 97/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.7357
# Epoch 98/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5304 - accuracy: 0.7461
# Epoch 99/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5277 - accuracy: 0.7448
# Epoch 100/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5205 - accuracy: 0.7266
# Epoch 101/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5315 - accuracy: 0.7318
# Epoch 102/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.7435
# Epoch 103/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5464 - accuracy: 0.7409
# Epoch 104/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7253
# Epoch 105/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7396
# Epoch 106/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5265 - accuracy: 0.7279
# Epoch 107/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5197 - accuracy: 0.7370
# Epoch 108/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5240 - accuracy: 0.7396
# Epoch 109/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 0.7526
# Epoch 110/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5161 - accuracy: 0.7474
# Epoch 111/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5165 - accuracy: 0.7422
# Epoch 112/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5226 - accuracy: 0.7435
# Epoch 113/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5461 - accuracy: 0.7331
# Epoch 114/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5152 - accuracy: 0.7344
# Epoch 115/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5110 - accuracy: 0.7539
# Epoch 116/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5055 - accuracy: 0.7526
# Epoch 117/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5095 - accuracy: 0.7474
# Epoch 118/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5079 - accuracy: 0.7526
# Epoch 119/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.7773
# Epoch 120/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5145 - accuracy: 0.7474
# Epoch 121/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5287 - accuracy: 0.7513
# Epoch 122/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5076 - accuracy: 0.7422
# Epoch 123/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5105 - accuracy: 0.7526
# Epoch 124/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7500
# Epoch 125/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5234 - accuracy: 0.7344
# Epoch 126/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5249 - accuracy: 0.7461
# Epoch 127/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7617
# Epoch 128/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5068 - accuracy: 0.7448
# Epoch 129/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.7500
# Epoch 130/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5076 - accuracy: 0.7448
# Epoch 131/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5216 - accuracy: 0.7305
# Epoch 132/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5222 - accuracy: 0.7435
# Epoch 133/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5222 - accuracy: 0.7539
# Epoch 134/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.7448
# Epoch 135/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.7383
# Epoch 136/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5111 - accuracy: 0.7409
# Epoch 137/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5200 - accuracy: 0.7331
# Epoch 138/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5097 - accuracy: 0.7409
# Epoch 139/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4980 - accuracy: 0.7513
# Epoch 140/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5130 - accuracy: 0.7422
# Epoch 141/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5077 - accuracy: 0.7461
# Epoch 142/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5078 - accuracy: 0.7448
# Epoch 143/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.7617
# Epoch 144/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.7422
# Epoch 145/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.7409
# Epoch 146/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.7487
# Epoch 147/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4928 - accuracy: 0.7604
# Epoch 148/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5100 - accuracy: 0.7474
# Epoch 149/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4918 - accuracy: 0.7630
# Epoch 150/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5240 - accuracy: 0.7422

# %%
# evaluate the model
scores = model.evaluate(x,y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
from ann_visualizer.visualize import ann_viz;
ann_viz(model, title="Pima Diabetes Neural Network-Assignment 1")
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5808 - accuracy: 0.7174
#
# accuracy: 71.74%
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80         else:
# ---> 81             proc = subprocess.run(cmd, **kwargs)
#      82     except OSError as e:
#
# ~\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2492/698651358.py in <module>
#       3 print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
#       4 from ann_visualizer.visualize import ann_viz;
# ----> 5 ann_viz(model, title="Pima Diabetes Neural Network-Assignment 1")
#
# ~\anaconda3\lib\site-packages\ann_visualizer\visualize.py in ann_viz(model, view, filename, title)
#     204         g.edge_attr.update(arrowhead="none", color="#707070");
#     205         if view == True:
# --> 206             g.view();
#
# ~\anaconda3\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# ~\anaconda3\lib\site-packages\graphviz\rendering.py in view(self, filename, directory, cleanup, quiet, quiet_view)
#     183             and no way to retrieve the application's exit status.
#     184         """
# --> 185         return self.render(filename=filename, directory=directory, view=True,
#     186                            cleanup=cleanup, quiet=quiet, quiet_view=quiet_view)
#
# ~\anaconda3\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# ~\anaconda3\lib\site-packages\graphviz\rendering.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     120         args.append(filepath)
#     121
# --> 122         rendered = self._render(*args, **kwargs)
#     123
#     124         if cleanup:
#
# ~\anaconda3\lib\site-packages\graphviz\_tools.py in wrapper(*args, **kwargs)
#     169                               category=category)
#     170
# --> 171             return func(*args, **kwargs)
#     172
#     173         return wrapper
#
# ~\anaconda3\lib\site-packages\graphviz\backend\rendering.py in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     322     cmd += args
#     323
# --> 324     execute.run_check(cmd,
#     325                       cwd=filepath.parent if filepath.parent.parts else None,
#     326                       quiet=quiet,
#
# ~\anaconda3\lib\site-packages\graphviz\backend\execute.py in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82     except OSError as e:
#      83         if e.errno == errno.ENOENT:
# ---> 84             raise ExecutableNotFound(cmd) from e
#      85         raise
#      86
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH
